# %% [markdown]
# ### Importación de datos

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

tienda.head()
# Out:
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos  164300.0          6900.0
# 1    Mesa de comedor                Muebles  192300.0          8400.0
# 2      Juego de mesa               Juguetes  209600.0         15900.0
# 3         Microondas      Electrodomésticos  757500.0         41000.0
# 4   Silla de oficina                Muebles  335200.0         20200.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
# 2      15/03/2021   Juan Fernandez       Cartagena             1
# 3      03/05/2022   Juan Fernandez            Cali             4
# 4      07/11/2020    Maria Alfonso        Medellín             5
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   8   4.60971 -74.08175
# ...

# %% [markdown]
# #1. Análisis de facturación

# %%
ingreso_tienda1 = tienda['Precio'].sum()
ingreso_tienda2 = tienda2['Precio'].sum()
ingreso_tienda3 = tienda3['Precio'].sum()
ingreso_tienda4 = tienda4['Precio'].sum()

print(f"Ingreso total Tienda 1: {ingreso_tienda1}")
print(f"Ingreso total Tienda 2: {ingreso_tienda2}")
print(f"Ingreso total Tienda 3: {ingreso_tienda3}")
print(f"Ingreso total Tienda 4: {ingreso_tienda4}")
# Out:
# Ingreso total Tienda 1: 1150880400.0
# Ingreso total Tienda 2: 1116343500.0
# Ingreso total Tienda 3: 1098019600.0
# Ingreso total Tienda 4: 1038375700.0

# %% [markdown]
# # 2. Ventas por categoría

# %%
ventas_por_categoria_tienda1 = tienda['Categoría del Producto'].value_counts()


print("Ventas por categoría Tienda 1:")
display(ventas_por_categoria_tienda1)
# Out:
# Ventas por categoría Tienda 1:
# Categoría del Producto
# Muebles                    465
# Electrónicos               448
# Juguetes                   324
# Electrodomésticos          312
# Deportes y diversión       284
# Instrumentos musicales     182
# Libros                     173
# Artículos para el hogar    171
# Name: count, dtype: int64

# %%
ventas_por_categoria_tienda1 = tienda['Categoría del Producto'].value_counts()
ventas_por_categoria_tienda2 = tienda2['Categoría del Producto'].value_counts()
ventas_por_categoria_tienda3 = tienda3['Categoría del Producto'].value_counts()
ventas_por_categoria_tienda4 = tienda4['Categoría del Producto'].value_counts()

print("Ventas por categoría Tienda 1:")
display(ventas_por_categoria_tienda1)

print("\nVentas por categoría Tienda 2:")
display(ventas_por_categoria_tienda2)

print("\nVentas por categoría Tienda 3:")
display(ventas_por_categoria_tienda3)

print("\nVentas por categoría Tienda 4:")
display(ventas_por_categoria_tienda4)
# Out:
# Ventas por categoría Tienda 1:
# Categoría del Producto
# Muebles                    465
# Electrónicos               448
# Juguetes                   324
# Electrodomésticos          312
# Deportes y diversión       284
# Instrumentos musicales     182
# Libros                     173
# Artículos para el hogar    171
# Name: count, dtype: int64
# Ventas por categoría Tienda 2:
# Categoría del Producto
# Muebles                    442
# Electrónicos               422
# Juguetes                   313
# Electrodomésticos          305
# Deportes y diversión       275
# Instrumentos musicales     224
# Libros                     197
# Artículos para el hogar    181
# Name: count, dtype: int64
# Ventas por categoría Tienda 3:
# Categoría del Producto
# Muebles                    499
# Electrónicos               451
# Juguetes                   315
# Electrodomésticos          278
# Deportes y diversión       277
# Libros                     185
# Instrumentos musicales     177
# ...

# %% [markdown]
# # 3. Calificación promedio de la tienda

# %%
calificacion_promedio_tienda1 = tienda['Calificación'].mean()
calificacion_promedio_tienda2 = tienda2['Calificación'].mean()
calificacion_promedio_tienda3 = tienda3['Calificación'].mean()
calificacion_promedio_tienda4 = tienda4['Calificación'].mean()

print(f"Calificación promedio Tienda 1: {calificacion_promedio_tienda1}")
print(f"Calificación promedio Tienda 2: {calificacion_promedio_tienda2}")
print(f"Calificación promedio Tienda 3: {calificacion_promedio_tienda3}")
print(f"Calificación promedio Tienda 4: {calificacion_promedio_tienda4}")
# Out:
# Calificación promedio Tienda 1: 3.976685036032217
# Calificación promedio Tienda 2: 4.037303942348453
# Calificación promedio Tienda 3: 4.048325561678677
# Calificación promedio Tienda 4: 3.9957591178965224

# %% [markdown]
# # 4. Productos más y menos vendidos

# %%
productos_mas_vendidos_tienda1 = tienda['Producto'].value_counts().head()
productos_menos_vendidos_tienda1 = tienda['Producto'].value_counts().tail()

productos_mas_vendidos_tienda2 = tienda2['Producto'].value_counts().head()
productos_menos_vendidos_tienda2 = tienda2['Producto'].value_counts().tail()

productos_mas_vendidos_tienda3 = tienda3['Producto'].value_counts().head()
productos_menos_vendidos_tienda3 = tienda3['Producto'].value_counts().tail()

productos_mas_vendidos_tienda4 = tienda4['Producto'].value_counts().head()
productos_menos_vendidos_tienda4 = tienda4['Producto'].value_counts().tail()


print("Productos más vendidos Tienda 1:")
display(productos_mas_vendidos_tienda1)
print("\nProductos menos vendidos Tienda 1:")
display(productos_menos_vendidos_tienda1)

print("\nProductos más vendidos Tienda 2:")
display(productos_mas_vendidos_tienda2)
print("\nProductos menos vendidos Tienda 2:")
display(productos_menos_vendidos_tienda2)

print("\nProductos más vendidos Tienda 3:")
display(productos_mas_vendidos_tienda3)
print("\nProductos menos vendidos Tienda 3:")
display(productos_menos_vendidos_tienda3)

print("\nProductos más vendidos Tienda 4:")
display(productos_mas_vendidos_tienda4)
print("\nProductos menos vendidos Tienda 4:")
display(productos_menos_vendidos_tienda4)
# Out:
# Productos más vendidos Tienda 1:
# Producto
# Microondas          60
# TV LED UHD 4K       60
# Armario             60
# Secadora de ropa    58
# Mesa de noche       56
# Name: count, dtype: int64
# Productos menos vendidos Tienda 1:
# Producto
# Ciencia de datos con Python    39
# Pandereta                      36
# Olla de presión                35
# Auriculares con micrófono      33
# Celular ABXY                   33
# Name: count, dtype: int64
# Productos más vendidos Tienda 2:
# Producto
# Iniciando en programación    65
# Microondas                   62
# Batería                      61
# Guitarra acústica            58
# Pandereta                    58
# Name: count, dtype: int64
# Productos menos vendidos Tienda 2:
# Producto
# Auriculares        37
# Sillón             35
# Mesa de comedor    34
# Impresora          34
# Juego de mesa      32
# Name: count, dtype: int64
# Productos más vendidos Tienda 3:
# Producto
# Kit de bancas      57
# Mesa de comedor    56
# ...

# %% [markdown]
# # 5. Envío promedio por tienda

# %%
costo_envio_promedio_tienda1 = tienda['Costo de envío'].mean()
costo_envio_promedio_tienda2 = tienda2['Costo de envío'].mean()
costo_envio_promedio_tienda3 = tienda3['Costo de envío'].mean()
costo_envio_promedio_tienda4 = tienda4['Costo de envío'].mean()

print(f"Costo de envío promedio Tienda 1: {costo_envio_promedio_tienda1}")
print(f"Costo de envío promedio Tienda 2: {costo_envio_promedio_tienda2}")
print(f"Costo de envío promedio Tienda 3: {costo_envio_promedio_tienda3}")
print(f"Costo de envío promedio Tienda 4: {costo_envio_promedio_tienda4}")
# Out:
# Costo de envío promedio Tienda 1: 26018.60958033065
# Costo de envío promedio Tienda 2: 25216.235693090293
# Costo de envío promedio Tienda 3: 24805.680373039424
# Costo de envío promedio Tienda 4: 23459.457167090754

# %%
# @title Graficos de resultados
import matplotlib.pyplot as plt

ingresos = {
    'Tienda 1': ingreso_tienda1,
    'Tienda 2': ingreso_tienda2,
    'Tienda 3': ingreso_tienda3,
    'Tienda 4': ingreso_tienda4
}

tiendas = list(ingresos.keys())
valores_ingreso = list(ingresos.values())

plt.figure(figsize=(10, 6))
plt.bar(tiendas, valores_ingreso, color='skyblue')
plt.xlabel('Tienda')
plt.ylabel('Ingreso Total')
plt.title('Ingreso Total por Tienda')
plt.show()

# %%
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(15, 10))
fig.suptitle('Top 5 Productos Más Vendidos por Tienda', fontsize=16)

axes[0, 0].pie(productos_mas_vendidos_tienda1.values, labels=productos_mas_vendidos_tienda1.index, autopct='%1.1f%%', startangle=90)
axes[0, 0].set_title('Tienda 1')

axes[0, 1].pie(productos_mas_vendidos_tienda2.values, labels=productos_mas_vendidos_tienda2.index, autopct='%1.1f%%', startangle=90)
axes[0, 1].set_title('Tienda 2')

axes[1, 0].pie(productos_mas_vendidos_tienda3.values, labels=productos_mas_vendidos_tienda3.index, autopct='%1.1f%%', startangle=90)
axes[1, 0].set_title('Tienda 3')

axes[1, 1].pie(productos_mas_vendidos_tienda4.values, labels=productos_mas_vendidos_tienda4.index, autopct='%1.1f%%', startangle=90)
axes[1, 1].set_title('Tienda 4')

plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()

# %%
# Combine the sales by category dataframes
ventas_por_categoria_combinado = pd.DataFrame({
    'Tienda 1': ventas_por_categoria_tienda1,
    'Tienda 2': ventas_por_categoria_tienda2,
    'Tienda 3': ventas_por_categoria_tienda3,
    'Tienda 4': ventas_por_categoria_tienda4
})

# Fill NaN values with 0
ventas_por_categoria_combinado = ventas_por_categoria_combinado.fillna(0)

# Plot the stacked bar chart
ventas_por_categoria_combinado.plot(kind='bar', stacked=True, figsize=(15, 8))
plt.title('Ventas por Categoría del Producto por Tienda')
plt.xlabel('Categoría del Producto')
plt.ylabel('Cantidad Vendida')
plt.xticks(rotation=90)
plt.legend(title='Tienda')
plt.tight_layout()
plt.show()

# %%
calificaciones = {
    'Tienda 1': calificacion_promedio_tienda1,
    'Tienda 2': calificacion_promedio_tienda2,
    'Tienda 3': calificacion_promedio_tienda3,
    'Tienda 4': calificacion_promedio_tienda4
}

tiendas = list(calificaciones.keys())
valores_calificacion = list(calificaciones.values())

plt.figure(figsize=(10, 6))
plt.plot(tiendas, valores_calificacion, marker='o', linestyle='-', color='lightgreen')
plt.xlabel('Tienda')
plt.ylabel('Calificación Promedio')
plt.title('Calificación Promedio por Tienda')
plt.ylim(0, 5) # Ratings are typically on a scale of 1-5
plt.grid(True)
plt.show()

# %% [markdown]
# ## Comparación de Tiendas por Métricas Clave
#
# ### Ingreso Total:
# La Tienda con mayor ingreso total es la Tienda 1 con 1150880400.00.
# La Tienda con menor ingreso total es la Tienda 4 con 1038375700.00.
# Las tiendas se clasifican por ingreso total de mayor a menor de la siguiente manera: Tienda 1 > Tienda 2 > Tienda 3 > Tienda 4.
#
# ### Calificación Promedio:
# La Tienda con la calificación promedio más alta es la Tienda 3 con 4.05.
# La Tienda con la calificación promedio más baja es la Tienda 1 con 3.98.
# Las calificaciones promedio son muy similares entre todas las tiendas, todas por encima de 3.9.
#
# ### Costo de Envío Promedio:
# La Tienda con el costo de envío promedio más bajo es la Tienda 4 con 23459.46.
# La Tienda con el costo de envío promedio más alto es la Tienda 1 con 26018.61.
# Existe una clara diferencia en los costos de envío promedio, con la Tienda 4 siendo la más económica en este aspecto.
#
# ### Ventas por Categoría del Producto:
# Muebles y Electrónicos son las categorías más fuertes consistentemente en todas las tiendas.
# La Tienda 3 lidera en ventas de Muebles (499 unidades).
# Las Tiendas 1, 3 y 4 tienen un rendimiento similar en Electrónicos (448, 451, 451 unidades respectivamente).
# La Tienda 4 destaca en Juguetes (338 unidades) y Artículos para el hogar (201 unidades).
# La Tienda 2 tiene un buen desempeño en Instrumentos musicales (224 unidades) y Libros (197 unidades).
# La Tienda 4 tiene las ventas más bajas en Electrodomésticos (254 unidades) e Instrumentos musicales (170 unidades).
#
# ### Productos Más Vendidos (Top 5):
# Los productos más vendidos varían significativamente entre las tiendas, sugiriendo diferentes especializaciones o demandas de los clientes.
# Tienda 1 tiene una fuerte venta de electrodomésticos y muebles.
# Tienda 2 muestra éxito en productos de programación, música y electrodomésticos.
# Tienda 3 se enfoca en muebles y artículos para el hogar.
# Tienda 4 sobresale en muebles, artículos para el hogar y productos de datos.
#
# ### Productos Menos Vendidos (Bottom 5):
# Los productos menos vendidos también difieren por tienda, indicando áreas de baja demanda o posible saturación.
# La Tienda 1 tiene bajas ventas en productos de datos y algunos electrónicos.
# La Tienda 2 muestra debilidad en algunos muebles y electrónicos/juguetes.
# La Tienda 3 tiene productos de música, hogar, y construcción entre los menos vendidos.
# La Tienda 4 presenta bajas ventas en electrodomésticos, productos de datos y música.
#
# ### Resumen de Comparaciones:
# - **Ingreso Total:** Tienda 1 es la líder.
# - **Calificación Promedio:** Tienda 3 tiene la calificación más alta, pero las diferencias son mínimas.
# - **Costo de Envío Promedio:** Tienda 4 es la más competitiva.
# - **Ventas por Categoría:** Muebles y Electrónicos son fuertes en general. Tienda 3 lidera en Muebles, Tienda 4 en Juguetes y Artículos para el hogar, y Tienda 2 en Instrumentos musicales y Libros.
# - **Productos Más/Menos Vendidos:** Cada tienda tiene un perfil de ventas de productos único, reflejando posibles nichos de mercado.
# ## Recomendación para Mr. Juan
#
# Basado en el análisis exhaustivo de las cuatro tiendas, la recomendación para Mr. Juan sobre dónde debería vender sus productos es la **Tienda 1**.
#
# ### Justificación de la Recomendación:
# Aunque cada tienda tiene sus fortalezas y debilidades, la Tienda 1 se destaca como la opción más prometedora para Mr. Juan por las siguientes razones:
#
# - **Mayor Ingreso Total:** La Tienda 1 generó el ingreso total más alto en comparación con las otras tiendas. Esto sugiere una base de clientes sólida y un volumen de ventas generalmente mayor, lo que podría traducirse en mayores oportunidades de ganancias para Mr. Juan.
#    - Ingreso Total Tienda 1: 1150880400.00
#    - Ingreso Total Tienda 2: 1116343500.00
#    - Ingreso Total Tienda 3: 1098019600.00
#    - Ingreso Total Tienda 4: 1038375700.00
#
# - **Fuerte Desempeño en Categorías Clave:** La Tienda 1 muestra un fuerte rendimiento en las categorías de Muebles y Electrónicos, que suelen ser de alto valor. Si los productos de Mr. Juan se alinean con estas categorías, existe un mercado ya establecido con alta demanda.
#
# - **Calificación Promedio Sólida:** Aunque no tiene la calificación más alta, la calificación promedio de la Tienda 1 es sólida y comparable a las otras tiendas. Esto indica que los clientes en esta tienda tienen una experiencia generalmente positiva.
#    - Calificación Promedio Tienda 1: 3.98
#    - Calificación Promedio Tienda 2: 4.04
#    - Calificación Promedio Tienda 3: 4.05
#    - Calificación Promedio Tienda 4: 4.00
#
# ### Consideraciones Adicionales:
# Es importante que Mr. Juan evalúe si su estructura de costos puede absorber el costo de envío promedio más alto de la Tienda 1. Sin embargo, el potencial de mayores ingresos podría compensar este factor.
#
# Si los productos de Mr. Juan se alinean más estrechamente con las fortalezas de otras tiendas (por ejemplo, Juguetes y Artículos para el hogar en la Tienda 4, o Instrumentos musicales y Libros en la Tienda 2), esas tiendas podrían ser alternativas viables. No obstante, para maximizar el potencial de ingresos basándose en el rendimiento general, la Tienda 1 es la opción recomendada.
#
# ### Fortalezas y Debilidades Resumidas de Cada Tienda para la Decisión de Mr. Juan:
#
# - **Tienda 1:**
#   - **Fortalezas:** Mayor ingreso total, fuerte en Muebles y Electrónicos, calificación promedio sólida.
#   - **Debilidades:** Costo de envío promedio más alto.
#
# - **Tienda 2:**
#   - **Fortalezas:** Segundo mayor ingreso total, calificación promedio ligeramente más alta, destaca en Instrumentos musicales y Libros.
#   - **Debilidades:** Ingreso total menor que Tienda 1.
#
# - **Tienda 3:**
#   - **Fortalezas:** Calificación promedio más alta, lidera en ventas de Muebles.
#   - **Debilidades:** Tercer lugar en ingreso total.
#
# - **Tienda 4:**
#   - **Fortalezas:** Costo de envío promedio más bajo, destaca en Juguetes y Artículos para el hogar.
#   - **Debilidades:** Menor ingreso total.
#
# # Recomendación para Mr. Juan: Análisis de Tiendas
#
# ## Introducción
#
# Este reporte tiene como objetivo recomendar a Mr. Juan la tienda más adecuada para vender sus productos, basándonos en un análisis detallado de los datos de cuatro tiendas existentes. Se han evaluado métricas clave como el ingreso total, las ventas por categoría de producto, la calificación promedio de los clientes, los productos más y menos vendidos, y los costos de envío promedio. El análisis y las visualizaciones generadas nos permitirán ofrecer una justificación sólida para la recomendación.
#
# ## Análisis de las Tiendas
#
# Hemos analizado individualmente el rendimiento de cada una de las cuatro tiendas para comprender sus fortalezas y debilidades.
#
# ### Tienda 1
#
# *   **Ingreso Total:** 1150880400.00
# *   **Calificación Promedio:** 3.98
# *   **Costo de Envío Promedio:** 26018.61
# *   **Ventas por Categoría:** Lidera en ingreso total y tiene un fuerte desempeño en Muebles y Electrónicos.
# *   **Productos Más Vendidos (Top 5):** ['Microondas', 'TV LED UHD 4K', 'Armario', 'Secadora de ropa', 'Mesa de noche']
# *   **Productos Menos Vendidos (Bottom 5):** ['Ciencia de datos con Python', 'Pandereta', 'Olla de presión', 'Auriculares con micrófono', 'Celular ABXY']
# *   **Fortalezas:** Mayor ingreso total, fuerte presencia en categorías de alto valor.
# *   **Debilidades:** Costo de envío promedio más alto.
#
# ### Tienda 2
#
# *   **Ingreso Total:** 1116343500.00
# *   **Calificación Promedio:** 4.04
# *   **Costo de Envío Promedio:** 25216.24
# *   **Ventas por Categoría:** Buen desempeño general, destacando en Instrumentos musicales y Libros.
# *   **Productos Más Vendidos (Top 5):** ['Iniciando en programación', 'Microondas', 'Batería', 'Guitarra acústica', 'Pandereta']
# *   **Productos Menos Vendidos (Bottom 5):** ['Auriculares', 'Sillón', 'Mesa de comedor', 'Impresora', 'Juego de mesa']
# *   **Fortalezas:** Segundo en ingreso total, buena calificación promedio.
# *   **Debilidades:** Ingreso total menor que Tienda 1.
#
# ### Tienda 3
#
# *   **Ingreso Total:** 1098019600.00
# *   **Calificación Promedio:** 4.05
# *   **Costo de Envío Promedio:** 24805.68
# *   **Ventas por Categoría:** Lidera en ventas de Muebles.
# *   **Productos Más Vendidos (Top 5):** ['Kit de bancas', 'Mesa de comedor', 'Cama king', 'Set de ollas', 'Mesa de noche']
# *   **Productos Menos Vendidos (Bottom 5):** ['Guitarra eléctrica', 'Set de vasos', 'Mochila', 'Microondas', 'Bloques de construcción']
# *   **Fortalezas:** La calificación promedio más alta, fuerte en Muebles.
# *   **Debilidades:** Tercera en ingreso total.
#
# ### Tienda 4
#
# *   **Ingreso Total:** 1038375700.00
# *   **Calificación Promedio:** 4.00
# *   **Costo de Envío Promedio:** 23459.46
# *   **Ventas por Categoría:** Destaca en Juguetes y Artículos para el hogar.
# *   **Productos Más Vendidos (Top 5):** ['Cama box', 'Cubertería', 'Dashboards con Power BI', 'Cama king', 'Carrito de control remoto']
# *   **Productos Menos Vendidos (Bottom 5):** ['Refrigerador', 'Ciencia de datos con Python', 'Guitarra acústica', 'Armario', 'Guitarra eléctrica']
# *   **Fortalezas:** El costo de envío promedio más bajo.
# *   **Debilidades:** El menor ingreso total, bajas ventas en algunas categorías como Electrodomésticos e Instrumentos musicales.
#
# ## Comparación de Tiendas
#
# Al comparar las tiendas, observamos lo siguiente:
#
# *   **Ingreso Total:** La Tienda 1 claramente lidera en este aspecto, como se visualiza en el gráfico de barras de "Ingreso Total por Tienda".
# *   **Calificación Promedio:** Las calificaciones son muy similares entre todas las tiendas, todas por encima de 3.9, lo que indica una satisfacción general del cliente. La Tienda 3 tiene una ligera ventaja. El gráfico de línea de "Calificación Promedio por Tienda" ilustra esta similitud.
# *   **Costo de Envío Promedio:** La Tienda 4 tiene el costo de envío más bajo, mientras que la Tienda 1 tiene el más alto.
# *   **Ventas por Categoría:** El gráfico de barras apiladas de "Ventas por Categoría del Producto por Tienda" muestra que Muebles y Electrónicos son consistentemente las categorías con mayores ventas en todas las tiendas. La Tienda 3 tiene la mayor cantidad de ventas de Muebles, mientras que las Tiendas 1, 3 y 4 tienen ventas similares en Electrónicos.
# *   **Productos Más/Menos Vendidos:** Los gráficos circulares del "Top 5 Productos Más Vendidos por Tienda" resaltan que las tiendas tienen diferentes productos populares, lo que sugiere especializaciones o demandas de nicho.
#
# ## Justificación de la Recomendación
#
# Basado en el análisis de los datos, la recomendación para Mr. Juan es vender sus productos en la **Tienda 1**.
#
# La principal razón para esta recomendación es el **alto ingreso total** de la Tienda 1. Como se evidencia en el gráfico de barras de Ingreso Total, la Tienda 1 supera a las otras tiendas en términos de ingresos generados. Un mayor ingreso total generalmente se traduce en un mayor volumen de ventas y una base de clientes más grande, lo que ofrece a Mr. Juan la mejor oportunidad para maximizar sus ventas y, por lo tanto, sus ganancias potenciales.
#
# Además del alto ingreso total, la Tienda 1 demuestra un **fuerte desempeño en categorías de productos clave** como Muebles y Electrónicos. Si los productos de Mr. Juan pertenecen a estas categorías, la Tienda 1 ya tiene un mercado establecido con alta demanda. El gráfico de barras apiladas de Ventas por Categoría ilustra cómo Muebles y Electrónicos contribuyen significativamente a las ventas totales en la Tienda 1.
#
# Aunque la Tienda 1 tiene el costo de envío promedio más alto y una calificación promedio ligeramente menor que las otras tiendas, la diferencia en las calificaciones es mínima y el potencial de ingresos significativamente mayor en la Tienda 1 probablemente compensa el costo de envío adicional. La sólida calificación promedio (por encima de 3.9) indica que, a pesar de no ser la más alta, la experiencia general del cliente en la Tienda 1 es positiva.
#
# Las otras tiendas, si bien tienen sus propias fortalezas (por ejemplo, costo de envío bajo en la Tienda 4, calificación alta en la Tienda 3), no alcanzan el mismo nivel de ingreso total que la Tienda 1. La Tienda 4, a pesar de sus bajos costos de envío, tiene el ingreso total más bajo. Las Tiendas 2 y 3 tienen ingresos intermedios y fortalezas en categorías más específicas que pueden o no alinearse con los productos de Mr. Juan.
#
# ## Conclusión
#
# Considerando el objetivo de Mr. Juan de maximizar sus ventas y ingresos, la **Tienda 1** se presenta como la opción más favorable. Su liderazgo en ingreso total y su sólido desempeño en categorías de alta demanda ofrecen el mejor potencial de crecimiento. Si bien existen factores como el costo de envío a considerar, el potencial de ingresos de la Tienda 1 la convierte en la elección más estratégica basada en los datos analizados.
